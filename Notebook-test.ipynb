# %% [markdown]
# ## Flights with a focus on India

# %% [markdown]
# Our team of elite Data Scientists is focusing on analyzing Commercial Airflight data within India, utilizing datasets that encompass airline operations, airplane models, airport locations, and flight routes. This initiative aims to enhance the understanding and efficiency of India's aviation sector through Python tools designed to map airports across the country, analyze flight distances and routes, and compare the usage of different airplane models. By concentrating on the wealth of data available, we are positioned to uncover insights into operational patterns, connectivity, and fleet utilization across India's diverse and rapidly growing aviation market. This comprehensive analysis is geared towards identifying opportunities for optimization and growth, shedding light on the complexities of air travel in India without a specific emphasis on sustainability. With the aim of contributing to a more informed and efficient aviation industry, our work seeks to pave the way for advancements in air travel management and strategic planning in India.

# %%
from Functions.air_traffic_data_test import AirTrafficData

# %%
india_env = AirTrafficData()

# %%
india_env.plot_airports_by_country("India")

# %% [markdown]
# From this map we can see there is an almost equal distribution of airports throughout India.

# %%
india_env.distance_analysis()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 india_env.distance_analysis()
#
# File ~\adpro\Functions\air_traffic_data_test.py:118, in AirTrafficData.distance_analysis(self)
#     115 data.rename(columns={"IATA_x": "Source-IATA", "IATA_y": "Destination-IATA"}, inplace=True)
#     116 data.drop(columns=["Airport ID_x", "Airport ID_y"], inplace=True)
# --> 118 data["Distance"] = data.apply(lambda row: self.calculate_distance(row["Source-IATA"], row["Destination-IATA"]), axis=1)
#     120 return data["Distance"].hist()
#
# File ~\anaconda3\envs\adpro\Lib\site-packages\pandas\core\frame.py:10034, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, **kwargs)
#   10022 from pandas.core.apply import frame_apply
#   10024 op = frame_apply(
#   10025     self,
#   10026     func=func,
#    (...)
#   10032     kwargs=kwargs,
#   10033 )
# > 10034 return op.apply().__finalize__(self, method="apply")
#
# File ~\anaconda3\envs\adpro\Lib\site-packages\pandas\core\apply.py:837, in FrameApply.apply(self)
#     834 elif self.raw:
#     835     return self.apply_raw()
# --> 837 return self.apply_standard()
#
# File ~\anaconda3\envs\adpro\Lib\site-packages\pandas\core\apply.py:965, in FrameApply.apply_standard(self)
#     964 def apply_standard(self):
# --> 965     results, res_index = self.apply_series_generator()
#     967     # wrap results
#     968     return self.wrap_results(results, res_index)
#
# File ~\anaconda3\envs\adpro\Lib\site-packages\pandas\core\apply.py:981, in FrameApply.apply_series_generator(self)
#     978 with option_context("mode.chained_assignment", None):
#     979     for i, v in enumerate(series_gen):
#     980         # ignore SettingWithCopy here in case the user mutates
# --> 981         results[i] = self.func(v, *self.args, **self.kwargs)
#     982         if isinstance(results[i], ABCSeries):
#     983             # If we have a view on v, we need to make a copy because
#     984             #  series_generator will swap out the underlying data
#     985             results[i] = results[i].copy(deep=False)
#
# File ~\adpro\Functions\air_traffic_data_test.py:118, in AirTrafficData.distance_analysis.<locals>.<lambda>(row)
#     115 data.rename(columns={"IATA_x": "Source-IATA", "IATA_y": "Destination-IATA"}, inplace=True)
#     116 data.drop(columns=["Airport ID_x", "Airport ID_y"], inplace=True)
# --> 118 data["Distance"] = data.apply(lambda row: self.calculate_distance(row["Source-IATA"], row["Destination-IATA"]), axis=1)
#     120 return data["Distance"].hist()
#
# File ~\adpro\Functions\air_traffic_data_test.py:49, in AirTrafficData.calculate_distance(self, airport_code1, airport_code2)
#      47 # Look up airport coordinates
#      48 coords1 = self.airports_df.loc[self.airports_df['IATA'] == airport_code1, ['Latitude', 'Longitude']].values
# ---> 49 coords2 = self.airports_df.loc[self.airports_df['IATA'] == airport_code2, ['Latitude', 'Longitude']].values
#      51 # Check if either code is invalid (empty array check)
#      52 if len(coords1) == 0 or len(coords2) == 0:
#
# File ~\anaconda3\envs\adpro\Lib\site-packages\pandas\core\indexing.py:1147, in _LocationIndexer.__getitem__(self, key)
#    1145     if self._is_scalar_access(key):
#    1146         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1147     return self._getitem_tuple(key)
#    1148 else:
#    1149     # we by definition only have the 0th axis
#    1150     axis = self.axis or 0
#
# File ~\anaconda3\envs\adpro\Lib\site-packages\pandas\core\indexing.py:1339, in _LocIndexer._getitem_tuple(self, tup)
#    1336 if self._multi_take_opportunity(tup):
#    1337     return self._multi_take(tup)
# -> 1339 return self._getitem_tuple_same_dim(tup)
#
# File ~\anaconda3\envs\adpro\Lib\site-packages\pandas\core\indexing.py:994, in _LocationIndexer._getitem_tuple_same_dim(self, tup)
#     991 if com.is_null_slice(key):
#     992     continue
# --> 994 retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     995 # We should never have retval.ndim < self.ndim, as that should
#     996 #  be handled by the _getitem_lowerdim call above.
#     997 assert retval.ndim == self.ndim
#
# File ~\anaconda3\envs\adpro\Lib\site-packages\pandas\core\indexing.py:1382, in _LocIndexer._getitem_axis(self, key, axis)
#    1379     if hasattr(key, "ndim") and key.ndim > 1:
#    1380         raise ValueError("Cannot index with multidimensional key")
# -> 1382     return self._getitem_iterable(key, axis=axis)
#    1384 # nested tuple slicing
#    1385 if is_nested_tuple(key, labels):
#
# File ~\anaconda3\envs\adpro\Lib\site-packages\pandas\core\indexing.py:1323, in _LocIndexer._getitem_iterable(self, key, axis)
#    1321 # A collection of keys
#    1322 keyarr, indexer = self._get_listlike_indexer(key, axis)
# -> 1323 return self.obj._reindex_with_indexers(
#    1324     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1325 )
#
# File ~\anaconda3\envs\adpro\Lib\site-packages\pandas\core\generic.py:5597, in NDFrame._reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    5594     indexer = ensure_platform_int(indexer)
#    5596 # TODO: speed up on homogeneous DataFrame objects (see _reindex_multi)
# -> 5597 new_data = new_data.reindex_indexer(
#    5598     index,
#    5599     indexer,
#    5600     axis=baxis,
#    5601     fill_value=fill_value,
#    5602     allow_dups=allow_dups,
#    5603     copy=copy,
#    5604 )
#    5605 # If we've made a copy once, no need to make another one
#    5606 copy = False
#
# File ~\anaconda3\envs\adpro\Lib\site-packages\pandas\core\internals\managers.py:663, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, only_slice, use_na_proxy)
#     660     raise IndexError("Requested axis not found in manager")
#     662 if axis == 0:
# --> 663     new_blocks = self._slice_take_blocks_ax0(
#     664         indexer,
#     665         fill_value=fill_value,
#     666         only_slice=only_slice,
#     667         use_na_proxy=use_na_proxy,
#     668     )
#     669 else:
#     670     new_blocks = [
#     671         blk.take_nd(
#     672             indexer,
#    (...)
#     678         for blk in self.blocks
#     679     ]
#
# File ~\anaconda3\envs\adpro\Lib\site-packages\pandas\core\internals\managers.py:768, in BaseBlockManager._slice_take_blocks_ax0(self, slice_or_indexer, fill_value, only_slice, use_na_proxy, ref_inplace_op)
#     766     blklocs = self.blklocs[slobj]
#     767 else:
# --> 768     blknos = algos.take_nd(
#     769         self.blknos, slobj, fill_value=-1, allow_fill=allow_fill
#     770     )
#     771     blklocs = algos.take_nd(
#     772         self.blklocs, slobj, fill_value=-1, allow_fill=allow_fill
#     773     )
#     775 # When filling blknos, make sure blknos is updated before appending to
#     776 # blocks list, that way new blkno is exactly len(blocks).
#
# File ~\anaconda3\envs\adpro\Lib\site-packages\pandas\core\array_algos\take.py:118, in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     115     return arr.take(indexer, fill_value=fill_value, allow_fill=allow_fill)
#     117 arr = np.asarray(arr)
# --> 118 return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#
# File ~\anaconda3\envs\adpro\Lib\site-packages\pandas\core\array_algos\take.py:163, in _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     158     out = np.empty(out_shape, dtype=dtype)
#     160 func = _get_take_nd_function(
#     161     arr.ndim, arr.dtype, out.dtype, axis=axis, mask_info=mask_info
#     162 )
# --> 163 func(arr, indexer, out, fill_value)
#     165 if flip_order:
#     166     out = out.T
#
# KeyboardInterrupt:

# %% [markdown]
# As displayed above, you can tell that half of the covered flights in the world are for routes under 2000 km. This brings to light the great potential there could be in creating a better transportation infrastructure to reduce short-haul flights and increase other, more sustainable methods of transport like trains.

# %%
india_env.flights_from_airport("DEL")

# %% [markdown]
# As imagined, the great majority of flights departing from Delhi Airport are within India, this could reflect the poor transport infrastracture (e.g. lack of trains).
#
# The second highest destination is UAE and the third is Afghanistan.

# %%
india_env.most_used_airplane_models(3, country="India")

# %% [markdown]
# It's interesting to observe that in all of India, only one airplane model is being used. However, the dataset seems incomplete due to a lot of missing values, especially concerning the "IATA code" values.

# %%
india_env.flights_from_country('India')

# %%
india_env.flights_from_country_3('India', cutoff_distance=500, internal=True)

# %% [markdown]
# https://www.statista.com/statistics/1185559/carbon-footprint-of-travel-per-kilometer-by-mode-of-transport/#:~:text=The%20carbon%20footprint%20of%20a%20domestic%20flight%20
#
#    - 255 grams of carbon dioxide on short-haul flight (<1000 km)
#    - 40 grams of carbon dioxide on the railway

# %% [markdown]
# As seen before, India mainly has within-country flights, where the second and third most used airports are UAE and Saudi Arabia. This is similar to as observed with Delhi.

# %%
AirTrafficData().airport_info('Thule Air Base')
